# %% [markdown]
# ### <center style="color:DarkBlue"> Bike Sharing Prediction </center>
# ##### <center> MASTER IN BUSINESS ANALYTICS AND BIG DATA </center>
# ##### <center> Statistical Programing in Python </center>
# #### <center style="color:Darkred">Team A</center>
# <center>  Benjamín Chumaceiro | Rosalía Contreras | Eduardo Cort Pons | Maria Joyce | Ignacio Mouawad | Srishti Singh </center>

# %% [markdown]
# # Objective

# %% [markdown]
# + Predict the count of total rental bikes
# + Clean the dataset to allow its further processing.
# + Explore all the features and analyze them visually
# + Use the feature engineering techniques to improve R2
# + Properly apply the evaluation methods and ideas (train, test splitting; cross-validation, chose the proper metric)
# + Tuning hyper parameters to improve results
# + Run models to predict R2 and understand the real performance of the proposed models
# + Learn python

# %% [markdown]
# # Steps Followed

# %% [markdown]
# 1. Reading and Preparing Data
# 2. Exploring Data for the first time
# 3. Data Cleaning
#     + Hunting NAs
#     + Transforming to categorical variables
#     + Plotting and removing Outliers
#     + Skewness of the variables
# 4. Explanatory Analysis
# 5. Feature Engineering
# 6. Dimensionality reduction: PCA and Removing final features
# 7. Models:
#     + Simple Linear model - Baseline Model
#     + Ridge Linear Regression
#     + Lasso Model with cross Validation
#     + Decision Tree Model with CV
#     + Random Forest Model with CV and Grid Search
#     + Random Forest Model with Random Search
#     + Simple Linear model with PCA
# 8. Conclusion

# %% [markdown]
# # Work Division

# %% [markdown]
# Work division and planning:
# We all worked as a team but each of us was in charge of the following parts:
#
# + Eduardo Cort Pons and Srishti Singh were dealing with data preparation, cleaning and dimensionality reduction.
# + María Joyce and Rosalía Contreras were doing feature engineering and Explanatory Analysis graphs.
# + Benjamin Chumaceiro and Ignacio Mouawad were in charged of running the models, unifying the code and reviewing.
#
# We had 7 meetings during the creation of the proyect to share what we have done and help each other.

# %% [markdown]
# # Data Reading and Preparation

# %%
# Importing Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# Sklearn libraries
from sklearn import metrics
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import cross_val_score

# %%
# Dowloading the data 

folder_path = 'data/'
hour_data = pd.read_csv(os.path.join(folder_path, 'hour.csv'), index_col = 'instant')
hour_data.head()
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# 1                 1  0.24  0.2879  0.81        0.0       3          13   16
# 2                 1  0.22  0.2727  0.80        0.0       8          32   40
# 3                 1  0.22  0.2727  0.80        0.0       5          27   32
# 4                 1  0.24  0.2879  0.75        0.0       3          10   13
# 5                 1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# # Exploring Data for the first time

# %% [markdown]
# The dataset is analysed to summarize their main features. There is a column that is an object and have to be changed into a datetime type in the data cleaning step.

# %%
hour_data.info()  #general info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17379 entries, 1 to 17379
# Data columns (total 16 columns):
# dteday        17379 non-null object
# season        17379 non-null int64
# yr            17379 non-null int64
# mnth          17379 non-null int64
# hr            17379 non-null int64
# holiday       17379 non-null int64
# weekday       17379 non-null int64
# workingday    17379 non-null int64
# weathersit    17379 non-null int64
# temp          17379 non-null float64
# atemp         17379 non-null float64
# hum           17379 non-null float64
# windspeed     17379 non-null float64
# casual        17379 non-null int64
# registered    17379 non-null int64
# cnt           17379 non-null int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 2.3+ MB

# %%
hour_data.describe()  #describe info
# Out:
#              season            yr          mnth            hr       holiday  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       2.501640      0.502561      6.537775     11.546752      0.028770
# std        1.106918      0.500008      3.438776      6.914405      0.167165
# min        1.000000      0.000000      1.000000      0.000000      0.000000
# 25%        2.000000      0.000000      4.000000      6.000000      0.000000
# 50%        3.000000      1.000000      7.000000     12.000000      0.000000
# 75%        3.000000      1.000000     10.000000     18.000000      0.000000
# max        4.000000      1.000000     12.000000     23.000000      1.000000
#
#             weekday    workingday    weathersit          temp         atemp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       3.003683      0.682721      1.425283      0.496987      0.475775
# std        2.005771      0.465431      0.639357      0.192556      0.171850
# min        0.000000      0.000000      1.000000      0.020000      0.000000
# 25%        1.000000      0.000000      1.000000      0.340000      0.333300
# 50%        3.000000      1.000000      1.000000      0.500000      0.484800
# 75%        5.000000      1.000000      2.000000      0.660000      0.621200
# max        6.000000      1.000000      4.000000      1.000000      1.000000
#
#                 hum     windspeed        casual    registered           cnt
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.627229      0.190098     35.676218    153.786869    189.463088
# std        0.192930      0.122340     49.305030    151.357286    181.387599
# min        0.000000      0.000000      0.000000      0.000000      1.000000
# 25%        0.480000      0.104500      4.000000     34.000000     40.000000
# 50%        0.630000      0.194000     17.000000    115.000000    142.000000
# 75%        0.780000      0.253700     48.000000    220.000000    281.000000
# max        1.000000      0.850700    367.000000    886.000000    977.000000

# %% [markdown]
# ### Ensuring data quality.
# #### Uniqueness:
# In this point we check the uniqueness of each feature: with only one value is imposible to predict anything. All columns have more than 1 value.

# %%
#Looking for unique values of each feature
hour_data.nunique()
# Out:
# dteday        731
# season          4
# yr              2
# mnth           12
# hr             24
# holiday         2
# weekday         7
# workingday      2
# weathersit      4
# temp           50
# atemp          65
# hum            89
# windspeed      30
# casual        322
# registered    776
# cnt           869
# dtype: int64

# %% [markdown]
# ### Dealing with 0
# If any row has a value 0 in the target variable, we remove the row. But we have to be careful because most of the features are zero because of their nature.

# %%
# Looking for values equal to zero
(hour_data.iloc[0:17379, 2:16] == 0).sum()
# Out:
# yr             8645
# mnth              0
# hr              726
# holiday       16879
# weekday        2502
# workingday     5514
# weathersit        0
# temp              0
# atemp             2
# hum              22
# windspeed      2180
# casual         1581
# registered       24
# cnt               0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
# Converting as date type the dates that are objects
hour_data.loc[:, "dteday"] = pd.to_datetime(hour_data.loc[:, "dteday"])

# %%
# Converting hours as time type
hour_data.loc[:, "hr_time"] = pd.to_timedelta(hour_data.hr, unit='h')
#hour_data

# %%
# Unifying date and time
hour_data.loc[:, "dteday"] = hour_data.loc[:, "dteday"] + hour_data.loc[:, "hr_time"]
hour_data.head()
# Out:
#                      dteday  season  yr  mnth  hr  holiday  weekday  \
# instant
# 1       2011-01-01 00:00:00       1   0     1   0        0        6
# 2       2011-01-01 01:00:00       1   0     1   1        0        6
# 3       2011-01-01 02:00:00       1   0     1   2        0        6
# 4       2011-01-01 03:00:00       1   0     1   3        0        6
# 5       2011-01-01 04:00:00       1   0     1   4        0        6
#
#          workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# instant
# 1                 0           1  0.24  0.2879  0.81        0.0       3
# 2                 0           1  0.22  0.2727  0.80        0.0       8
# 3                 0           1  0.22  0.2727  0.80        0.0       5
# 4                 0           1  0.24  0.2879  0.75        0.0       3
# 5                 0           1  0.24  0.2879  0.75        0.0       0
#
#          registered  cnt  hr_time
# instant
# 1                13   16 00:00:00
# 2                32   40 01:00:00
# 3                27   32 02:00:00
# 4                10   13 03:00:00
# 5                 1    1 04:00:00

# %% [markdown]
# ### Hunting NAs

# %% [markdown]
# NAN are not good for data. In this case, there are not any NaN in this dataset.

# %%
# we checked if any of the target variable is set as 0. These rows could be immediately removed. 
(hour_data.loc[:, "cnt"] == 0).sum()
# Out:
# 0

# %%
# Eventhough the .describe() already show that there are no missing values, we double checked.
(hour_data.isnull().sum(axis = 1) > 0).sum()
# Out:
# 0

# %% [markdown]
# We realize that a lot of the variables are 0 because of their nature and category.

# %% [markdown]
# ### Transforming to categorical variables

# %%
# categorical variables
hour_data['season'] = hour_data.season.astype('category')
hour_data['holiday'] = hour_data.holiday.astype('category')
hour_data['weekday'] = hour_data.weekday.astype('category')
hour_data['weathersit'] = hour_data.weathersit.astype('category')
hour_data['workingday'] = hour_data.workingday.astype('category')
hour_data['mnth'] = hour_data.mnth.astype('category')
hour_data['yr'] = hour_data.yr.astype('category')
hour_data['hr_time'] = hour_data.hr.astype('category')

# %%
hour_data.head()
# Out:
#                      dteday season yr mnth  hr holiday weekday workingday  \
# instant
# 1       2011-01-01 00:00:00      1  0    1   0       0       6          0
# 2       2011-01-01 01:00:00      1  0    1   1       0       6          0
# 3       2011-01-01 02:00:00      1  0    1   2       0       6          0
# 4       2011-01-01 03:00:00      1  0    1   3       0       6          0
# 5       2011-01-01 04:00:00      1  0    1   4       0       6          0
#
#         weathersit  temp   atemp   hum  windspeed  casual  registered  cnt  \
# instant
# 1                1  0.24  0.2879  0.81        0.0       3          13   16
# 2                1  0.22  0.2727  0.80        0.0       8          32   40
# 3                1  0.22  0.2727  0.80        0.0       5          27   32
# 4                1  0.24  0.2879  0.75        0.0       3          10   13
# 5                1  0.24  0.2879  0.75        0.0       0           1    1
#
#         hr_time
# instant
# 1             0
# 2             1
# 3             2
# 4             3
# 5             4

# %%
#Change hour_data's index to be the dteday column,in order to plot the raw data conveniently
hour_data.set_index('dteday',inplace=True)

# %%
type(hour_data.index) # it should now be a DatetimeIndex
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# ### Converting Categorical values to Dummies for Sklearn

# %%
# Before converting Categorical into dummies we want so save some of our categorical varialbles for our explanatory analysis
hour_EDA = hour_data

# %%
# Converting Categorical into dummies
# Loop that runs through the categorical columns, dummying them and removing the single column at the end (so that only categorical columns remain)
type(hour_data['season'])
hour_data =  pd.get_dummies(hour_data, columns=['season','holiday','weekday','workingday','weathersit','hr_time'] )

# %% [markdown]
# ### Removing Correlated Features

# %% [markdown]
# The objective is to remove correlated features than can't help to predict the target variable.

# %%
# Exploring correlations
correlation_matrix  = hour_data.corr() #correlations
correlation_matrix.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col1 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col2 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col3 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col4 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col5 {
#             background-color:  #d8dce2;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col6 {
#             background-color:  #dfdbd9;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col7 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col8 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col9 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col10 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col11 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col12 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col13 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col14 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col15 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col16 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col17 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col18 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col19 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col20 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col21 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col22 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col23 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col24 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col25 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col26 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col27 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col28 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col29 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col30 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col31 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col32 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col33 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col34 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col35 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col36 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col37 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col38 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col39 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col40 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col41 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col42 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col43 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col44 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col45 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col46 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col47 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col48 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col49 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row0_col50 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col2 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col3 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col4 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col5 {
#             background-color:  #f2cbb7;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col6 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col7 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_a268792c_f82a_11e9_86df_c869cdbcf5b4row1_col8 {
#             background-color:

# %% [markdown]
# **Removing some features from the dataset:**
# Based on analysis of the above Correlation Matrix, it was decided to remove some columns from the dataset because these columns have a high correlation with other features in the dataset, as follows:
#
# **atemp:**
# **atemp** and **temp** have a correlation coefficient of 0.99, which means that they are very highly positively correlated.
# They both have a correlation of 0.4 with the target variable, therefore it was decided to remove atemp as it does not add any value to our model.
#
# **casual:**
# We need to choose either **casual** or **registered** to use in the model, as we cannot use both, since:
# cnt = casual + registered.
#
# **registered** has a correlation coefficient of 0.97, which means that they are very highly positively correlated.
# **casual** has a correlation coefficient of 0.69.
# Therefore it was decided to remove **casual** as it is not as valuable a feature as **registered**.
# But because **Registered** is imposible to predict in the future dataset we decided to errase both since they are the same as cnt

# %%
hour_data = hour_data.drop(['atemp', 'casual','registered'], axis=1) # Errasing features according correlation

correlation_matrix  = hour_data.corr() #correlations
correlation_matrix.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col1 {
#             background-color:  #d1dae9;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col2 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col3 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col4 {
#             background-color:  #e7d7ce;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col5 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col6 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col7 {
#             background-color:  #8db0fe;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col8 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col9 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col10 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col11 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col12 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col13 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col14 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col15 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col16 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col17 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col18 {
#             background-color:  #dcdddd;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col19 {
#             background-color:  #dddcdc;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col20 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col21 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col22 {
#             background-color:  #9fbfff;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col23 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col24 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col25 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col26 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col27 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col28 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col29 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col30 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col31 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col32 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col33 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col34 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col35 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col36 {
#             background-color:  #5a78e4;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col37 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col38 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col39 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col40 {
#             background-color:  #8badfd;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col41 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col42 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col43 {
#             background-color:  #93b5fe;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col44 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col45 {
#             background-color:  #a3c2fe;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col46 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row0_col47 {
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col0 {
#             background-color:  #b3cdfb;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col2 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col3 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col4 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col6 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col7 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col8 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col9 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col10 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_a2e4ef0c_f82a_11e9_86df_c869cdbcf5b4row1_col11 {
#             background-color:  #

# %% [markdown]
# ## Plotting and Treatment of Outliers

# %% [markdown]
# Let's plot the Outliers for these features which are weather related.
# * cnt
# * temp
# * windspeed
# * hum

# %%
fig,ax = plt.subplots(ncols=1)
sns.boxplot(data=hour_data[['temp', 'windspeed', 'hum']],ax=ax)

# %% [markdown]
# As seen in the Boxplot, the **windspeed** has outliers which begin from around 0.5 upwards.  To lessen the impact of these outliers on the **windspeed** feature, we will use the clip function to trim values above a suitable threshold.
# In this case, above 0.6.
# All values above this threshold will be set to 0.6.
#
# As seen in the Boxplot, the **hum** has outliers which are from below around 0.1 and lower.  To lessen the impact of these outliers on the **hum** feature, we will use the clip function to trim values below a suitable threshold.
# In this case, below 0.05.
# All values above this threshold will be set to 0.05.

# %%
hour_data["windspeed"] = hour_data["windspeed"].clip(upper=0.6)
hour_data["hum"] = hour_data["hum"].clip(lower=0.05)

# %% [markdown]
# Create the boxplot again to see that the outliers have been suitably clipped.

# %%
fig,ax = plt.subplots(ncols=1)
sns.boxplot(data=hour_data[['temp', 'windspeed', 'hum']],ax=ax)

# %% [markdown]
# ## Skewness of the variables

# %% [markdown]
# Lets now look at the skewness of the target variable, and of the numeric variables:
# * cnt
# * temp
# * windspeed
# * hum

# %% [markdown]
# Lets plot some histograms and look at the distributions.
#
# Firstly, the target variable, cnt.

# %%
plt.hist(hour_data['cnt'])
# Out:
# (array([6972., 3705., 2659., 1660.,  987.,  663.,  369.,  188.,  139.,
#           37.]),
#  array([  1. ,  98.6, 196.2, 293.8, 391.4, 489. , 586.6, 684.2, 781.8,
#         879.4, 977. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# From the plot above, the target variable's data appears to be right skewed.
# Therefore, we will replace the value of hour_data['cnt'] with its square root in order to flatten it.

# %%
hour_data['cnt'] = np.sqrt(hour_data['cnt'])

# %% [markdown]
# Plot the histogram again, to see if the skewdness has been flattened:

# %%
plt.hist(hour_data['cnt'])
# Out:
# (array([2653., 2168., 2254., 2714., 2764., 2076., 1380.,  840.,  379.,
#          151.]),
#  array([ 1.        ,  4.02569992,  7.05139984, 10.07709976, 13.10279969,
#         16.12849961, 19.15419953, 22.17989945, 25.20559937, 28.23129929,
#         31.25699922]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# It has flattened.

# %% [markdown]
# Next, the features temp and windspeed.

# %%
plt.hist(hour_data['temp'], color='lightblue');

# %% [markdown]
# The temp distribution does not look skewed.  Therefore, we do not need to flatten it.

# %% [markdown]
# Next, windspeed:

# %%
plt.hist(hour_data['windspeed'], color='steelblue');

# %% [markdown]
# From the plot above, the windspeed variable's data appears to be right skewed.
# Therefore, we will replace the value of hour_data['windspeed'] with its square root in order to flatten it.

# %%
hour_data['windspeed4'] = np.sqrt(hour_data['windspeed'])
plt.hist(hour_data['windspeed4'], color='steelblue')
# Out:
# (array([2180.,    0.,    0., 1425., 3355., 3352., 3856., 1870.,  999.,
#          342.]),
#  array([0.        , 0.07745967, 0.15491933, 0.232379  , 0.30983867,
#         0.38729833, 0.464758  , 0.54221767, 0.61967734, 0.697137  ,
#         0.77459667]),
#  <a list of 10 Patch objects>)

# %%
hour_data.head()
# Out:
#                     yr mnth  hr  temp   hum  windspeed       cnt  season_1  \
# dteday
# 2011-01-01 00:00:00  0    1   0  0.24  0.81        0.0  4.000000         1
# 2011-01-01 01:00:00  0    1   1  0.22  0.80        0.0  6.324555         1
# 2011-01-01 02:00:00  0    1   2  0.22  0.80        0.0  5.656854         1
# 2011-01-01 03:00:00  0    1   3  0.24  0.75        0.0  3.605551         1
# 2011-01-01 04:00:00  0    1   4  0.24  0.75        0.0  1.000000         1
#
#                      season_2  season_3  ...  hr_time_15  hr_time_16  \
# dteday                                   ...
# 2011-01-01 00:00:00         0         0  ...           0           0
# 2011-01-01 01:00:00         0         0  ...           0           0
# 2011-01-01 02:00:00         0         0  ...           0           0
# 2011-01-01 03:00:00         0         0  ...           0           0
# 2011-01-01 04:00:00         0         0  ...           0           0
#
#                      hr_time_17  hr_time_18  hr_time_19  hr_time_20  \
# dteday
# 2011-01-01 00:00:00           0           0           0           0
# 2011-01-01 01:00:00           0           0           0           0
# 2011-01-01 02:00:00           0           0           0           0
# 2011-01-01 03:00:00           0           0           0           0
# 2011-01-01 04:00:00           0           0           0           0
#
#                      hr_time_21  hr_time_22  hr_time_23  windspeed4
# dteday
# 2011-01-01 00:00:00           0           0           0         0.0
# 2011-01-01 01:00:00           0           0           0         0.0
# 2011-01-01 02:00:00           0           0           0         0.0
# 2011-01-01 03:00:00           0           0           0         0.0
# 2011-01-01 04:00:00           0           0           0         0.0
#
# [5 rows x 51 columns]

# %% [markdown]
# ## Explanatory Analysis

# %%
hour_EDA['hr_time'] = hour_EDA.hr.astype('category')
sns.set_style('whitegrid')
sns.set_context('talk', font_scale=0.5, rc={"lines.linewidth": 1.5})
params = {'legend.fontsize': 'x-large', 'axes.labelsize': 'x-large','axes.titlesize':'x-large','xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large',}
plt.rcParams.update(params)
fig,ax = plt.subplots()
sns.pointplot(data=hour_EDA[['hr_time',
                           'cnt',
                           'season']], x='hr_time', y='cnt', hue='season', ax=ax)
ax.set(title="Season wise hourly distribution of counts")
# Out:
# [Text(0.5, 1.0, 'Season wise hourly distribution of counts')]

# %%
# Seasonal distribution of count
fig,ax = plt.subplots()
sns.barplot(data=hour_EDA[['season', 'cnt']],
              x='season', y='cnt', ax=ax)
sns.set_context('talk', font_scale=0.6, rc={"lines.linewidth": 1.5})
ax.set(title="Seasonal distribution of counts")
# Out:
# [Text(0.5, 1.0, 'Seasonal distribution of counts')]

# %%
# binning into 5 different temperature bins for ploting

bin_labels_temp = ['Very Cold', 'Cold', 'Mild', 'Hot', 'Very Hot']
hour_EDA['temperature_category'] = pd.qcut(hour_EDA['temp'],  q=[0, .2, .4, .6, .8, 1], labels = bin_labels_temp)
hour_EDA.head()
fig,ax = plt.subplots()
sns.barplot(data=hour_EDA[['temperature_category', 'cnt']], x = 'temperature_category', y = 'cnt', ax = ax)
ax.set(title="Distribution of counts by Temperature Category")
hour_EDA = hour_EDA.drop(["temperature_category"], axis=1)

# %%
type(hour_data)
# Out:
# pandas.core.frame.DataFrame

# %%
# Ploting distribution of counts by wheathersit
fig,ax = plt.subplots()
sns.barplot(data=hour_EDA[['weathersit',
                           'cnt']],
              x='weathersit',
              y='cnt',
              ax=ax)
sns.set_context('talk', font_scale=0.6, rc={"lines.linewidth": 1.5})
ax.set(title="Distribution of counts by weathersit")
# Out:
# [Text(0.5, 1.0, 'Distribution of counts by weathersit')]

# %% [markdown]
# Hourly Count graph where we can explore how many bicycles are use per hour

# %%
# %matplotlib inline
import seaborn; seaborn.set()
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# #### Weekly Count

# %% [markdown]
# Let's now gain more insight by resampling the data by week:

# %%
simple_hour_EDA = hour_EDA[["cnt", "registered"]] #only take these columns into the graph

# %%
weekly = simple_hour_EDA.resample('W').sum()
weekly.plot(style=[':', '--', '-'])
plt.ylabel('Weekly bicycle count');
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# %% [markdown]
# #### 30 day rolling mean

# %% [markdown]
# Another way that comes in handy for aggregating the data is to use a rolling mean, utilizing the pd.rolling_mean() function. Here we'll do a 30 day rolling mean of our data, making sure to center the window.

# %%
daily = simple_hour_EDA.resample('D').sum()
daily.rolling(30, center=True).sum().plot(style=[':', '--', '-'])
plt.ylabel('mean hourly count');
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# %% [markdown]
#  We are curious about how things change based on the day of the week:

# %%
by_weekday = simple_hour_EDA.groupby(hour_EDA.index.dayofweek).mean()
by_weekday.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
by_weekday.plot(style=[':', '--', '-']);
# note Jan 1st 2011, Saturday is a 6, Sunday is a 0. 
# e.g. 189 is the average of all Saturdays in the dataset
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)

# %% [markdown]
# Let's look at the hourly trend on weekdays versus weekends.

# %%
weekend_info_hour_EDA = hour_EDA[["cnt", "registered", "weekday"]] #only take these columns into the graph
#simple_hour_data = hour_data[["cnt", "casual", "registered"]] #only take these columns into the graph
weekend = np.where(weekend_info_hour_EDA.index.weekday < 5, 'Weekday', 'Weekend') #todo re-include the weekday into the plot
by_time = weekend_info_hour_EDA.groupby([weekend, weekend_info_hour_EDA.index.time]).mean()

# %% [markdown]
# Plot two panels side by side, for the Weekdays and Weekends

# %%
#Todo: use same scale for both
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(14, 5))

by_time.loc['Weekday'].plot(ax=ax[0], title='Weekdays',
                            style=[':', '--', '-'])
by_time.loc['Weekend'].plot(ax=ax[1], title='Weekends',
                            style=[':', '--', '-']);

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# Lets use Binning to create some new features for use in the model
#
# Our first feature is "time of day" which is day bin by specific ranges of time

# %%
# Creating time of day
hour_data["time_of_day"] = 0

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# Binning time of day:
hour_data["time_of_day"][(hour_data["hr"] > 6) & (hour_data["hr"] < 13)] = 1
hour_data["time_of_day"][(hour_data["hr"] > 12) & (hour_data["hr"] < 19)] = 2
hour_data["time_of_day"][(hour_data["hr"] > 18) & (hour_data["hr"] < 22)] = 3
hour_data["time_of_day"][(hour_data["hr"] > 21) & (hour_data["hr"] < 24)] = 4
hour_data["time_of_day"].head()
# Out:
# dteday
# 2011-01-01 00:00:00    0
# 2011-01-01 01:00:00    0
# 2011-01-01 02:00:00    0
# 2011-01-01 03:00:00    0
# 2011-01-01 04:00:00    0
# Name: time_of_day, dtype: int64

# %%
hour_data['hr'] = hour_data.hr.astype('category')
hour_data["time_of_day"].head()
hour_data = hour_data.drop(["hr"], axis=1)

# %% [markdown]
# Since temp is an important feature, lets create 5 bins for the temperature ranges.
# We will use the same ones used in the plot above.

# %%
# binning into 5 different temperature bins

# They will be in order from 0 - 4, 0 being the coldest
hour_data['temperature_bin'] = pd.qcut(hour_data['temp'],  q=[0, .2, .4, .6, .8, 1],
                                    labels=False, precision=0)

# %% [markdown]
# Next, binning for humidity.

# %%
# binning into 5 different humidity bins

# They will be in order from 0 - 4, 0 being the coldest
hour_data['humidity_bin'] = pd.qcut(hour_data['hum'],  q=[0, .2, .4, .6, .8, 1],
                                    labels=False, precision=0)

# %% [markdown]
# Checking correlation with new features

# %%
correlation_matrix  = hour_data.corr() #correlations
correlation_matrix.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col1 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col2 {
#             background-color:  #7ea1fa;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col3 {
#             background-color:  #edd1c2;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col5 {
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col6 {
#             background-color:  #f5a081;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col7 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col8 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col9 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col10 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col11 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col12 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col13 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col14 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col15 {
#             background-color:  #7da0f9;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col16 {
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col17 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col18 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col19 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col20 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col21 {
#             background-color:  #8caffe;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col22 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col23 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col24 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col25 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col26 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col27 {
#             background-color:  #7699f6;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col28 {
#             background-color:  #6788ee;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col29 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col30 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col31 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col32 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col33 {
#             background-color:  #516ddb;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col34 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col35 {
#             background-color:  #6687ed;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col36 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col37 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col38 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col39 {
#             background-color:  #779af7;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col40 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col41 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col42 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col43 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col44 {
#             background-color:  #465ecf;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col45 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col46 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col47 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col48 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col49 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row0_col50 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col0 {
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col4 {
#             background-color:  #98b9ff;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col5 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col6 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col7 {
#             background-color:  #abc8fd;
#             color:  #000000;
#         }    #T_a8703bde_f82a_11e9_86df_c869cdbcf5b4row1_col8 {
#             background-color:

# %%
#hour_data.summary()
hour_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17379 entries, 2011-01-01 00:00:00 to 2012-12-31 23:00:00
# Data columns (total 53 columns):
# yr                 17379 non-null category
# mnth               17379 non-null category
# temp               17379 non-null float64
# hum                17379 non-null float64
# windspeed          17379 non-null float64
# cnt                17379 non-null float64
# season_1           17379 non-null uint8
# season_2           17379 non-null uint8
# season_3           17379 non-null uint8
# season_4           17379 non-null uint8
# holiday_0          17379 non-null uint8
# holiday_1          17379 non-null uint8
# weekday_0          17379 non-null uint8
# weekday_1          17379 non-null uint8
# weekday_2          17379 non-null uint8
# weekday_3          17379 non-null uint8
# weekday_4          17379 non-null uint8
# weekday_5          17379 non-null uint8
# weekday_6          17379 non-null uint8
# workingday_0       17379 non-null uint8
# workingday_1       17379 non-null uint8
# weathersit_1       17379 non-null uint8
# weathersit_2       17379 non-null uint8
# weathersit_3       17379 non-null uint8
# weathersit_4       17379 non-null uint8
# hr_time_0          17379 non-null uint8
# hr_time_1          17379 non-null uint8
# hr_time_2          17379 non-null uint8
# hr_time_3          17379 non-null uint8
# hr_time_4          17379 non-null uint8
# hr_time_5          17379 non-null uint8
# hr_time_6          17379 non-null uint8
# hr_time_7          17379 non-null uint8
# hr_time_8          17379 non-null uint8
# hr_time_9          17379 non-null uint8
# hr_time_10         17379 non-null uint8
# hr_time_11         17379 non-null uint8
# hr_time_12         17379 non-null uint8
# hr_time_13         17379 non-null uint8
# hr_time_14         17379 non-null uint8
# hr_time_15         17379 non-null uint8
# hr_time_16         17379 non-null uint8
# hr_time_17         17379 non-null uint8
# hr_time_18         17379 non-null uint8
# hr_time_19         17379 non-null uint8
# hr_time_20         17379 non-null uint8
# hr_time_21         17379 non-null uint8
# hr_time_22         17379 non-null uint8
# hr_time_23         17379 non-null uint8
# windspeed4         17379 non-null float64
# time_of_day        17379 non-null int64
# temperature_bin    17379 non-null int64
# humidity_bin       17379 non-null int64
# dtypes: category(2), float64(5), int64(3), uint8(43)
# memory usage: 2.6 MB

# %% [markdown]
# After generating the matrix again, the list of the most important features looks like this:

# %% [markdown]
# Feature Name  | Correlation
# ------------- | -------------
# Temp |0.42
# time_of_day |0.42
# temp and temperature_bin |0.41
# hum |-0.35
# hum and humidity_bin |-0.34
# yr |0.25
# windspeed |0.11
# windspeed4 |0.11

# %% [markdown]
# # Dimensionality reduction

# %% [markdown]
# ### PCA as dimensionality reduction
#
# Using PCA for dimensionality reduction involves zeroing out one or more of the smallest principal components, resulting in a lower-dimensional projection of the data that preserves the maximal data variance.

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
# Split the train set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)
#hour_data.drop('datetime', axis = 1).values #temporaty
XPCA = hour_data.drop('cnt', axis = 1).values
yPCA = hour_data['cnt'].values
hour_data.head()
# Out:
#                     yr mnth  temp   hum  windspeed       cnt  season_1  \
# dteday
# 2011-01-01 00:00:00  0    1  0.24  0.81        0.0  4.000000         1
# 2011-01-01 01:00:00  0    1  0.22  0.80        0.0  6.324555         1
# 2011-01-01 02:00:00  0    1  0.22  0.80        0.0  5.656854         1
# 2011-01-01 03:00:00  0    1  0.24  0.75        0.0  3.605551         1
# 2011-01-01 04:00:00  0    1  0.24  0.75        0.0  1.000000         1
#
#                      season_2  season_3  season_4  ...  hr_time_18  \
# dteday                                             ...
# 2011-01-01 00:00:00         0         0         0  ...           0
# 2011-01-01 01:00:00         0         0         0  ...           0
# 2011-01-01 02:00:00         0         0         0  ...           0
# 2011-01-01 03:00:00         0         0         0  ...           0
# 2011-01-01 04:00:00         0         0         0  ...           0
#
#                      hr_time_19  hr_time_20  hr_time_21  hr_time_22  \
# dteday
# 2011-01-01 00:00:00           0           0           0           0
# 2011-01-01 01:00:00           0           0           0           0
# 2011-01-01 02:00:00           0           0           0           0
# 2011-01-01 03:00:00           0           0           0           0
# 2011-01-01 04:00:00           0           0           0           0
#
#                      hr_time_23  windspeed4  time_of_day  temperature_bin  \
# dteday
# 2011-01-01 00:00:00           0         0.0            0                0
# 2011-01-01 01:00:00           0         0.0            0                0
# 2011-01-01 02:00:00           0         0.0            0                0
# 2011-01-01 03:00:00           0         0.0            0                0
# 2011-01-01 04:00:00           0         0.0            0                0
#
#                      humidity_bin
# dteday
# 2011-01-01 00:00:00             3
# 2011-01-01 01:00:00             3
# 2011-01-01 02:00:00             3
# 2011-01-01 03:00:00             3
# 2011-01-01 04:00:00             3
#
# [5 rows x 53 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=20)
pca.fit(XPCA)
X_pca = pca.transform(XPCA)
print("original shape:   ", XPCA.shape)
print("transformed shape:", X_pca.shape)
# Out:
# original shape:    (17379, 52)
# transformed shape: (17379, 20)

# %%
print(pca.explained_variance_)
# Out:
# [12.13242805  2.4308046   1.96348542  1.36983694  0.56397621  0.33591149
#   0.25230292  0.24708337  0.14947436  0.1442416   0.14306506  0.14236626
#   0.14134258  0.10329198  0.10042068  0.06695725  0.05936942  0.042418
#   0.04194529  0.04191702]

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');
plt.show()

# %% [markdown]
# ### Droping new generated features if needed

# %%
# We try combinations of features in manny models. In this code is where we automatize
hour_data = hour_data.drop(['temp','hum','windspeed'], axis=1)

# %% [markdown]
# # Splitting Dataset without using PCA

# %%
# Spliting Dataset into test
test_set = hour_data[hour_data.index >= "2012-10-01 00:00:00"]

# %%
# Spliting Dataset into training
train_set = hour_data[hour_data.index <= "2012-10-01 00:00:00"]

# %% [markdown]
# # Modeling

# %% [markdown]
# We ran 7 diferent types of model many time with diferent hiper parameters and using the new features created and also without the new features. The final result demostrated
#
# 1)Simple Linear model - Baseline Model
#
# 2)Ridge Linear Regression
#
# 3)Lasso Model with cross Validation
#
# 4)Decision Tree Model with CV
#
# 5)Random Forest Model with CV and Grid Search
#
# 6)Random Forest Model with Ramdom Search
#
# 7)Simple Linear model - Baseline Model simple

# %% [markdown]
# ## Simple Linear model - Baseline Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_absolute_error, mean_squared_error
# %matplotlib inline

# %%
# Split the train set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)

train_set = pd.DataFrame(train_set)
X = train_set.drop('cnt', axis = 1).values
y = train_set['cnt'].values
print(X.shape, y.shape)
# Out:
# (15212, 20) (15212,)

# %%
#Training the Algorithm
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Printing regresion coeficients
regressor.coef_
# Out:
# array([ 3.03501861e+00,  1.15485169e-01, -3.34834336e+00,  2.29245325e+12,
#         2.29245325e+12,  2.29245325e+12,  2.29245325e+12,  1.16815284e+12,
#         5.72276455e+11, -4.70940147e+11,  1.24936238e+11,  1.24936238e+11,
#         1.24936238e+11,  1.24936238e+11,  1.24936238e+11, -4.70940147e+11,
#         6.25375678e+11,  2.94992923e+10,  1.95680443e+12,  1.95680443e+12,
#         1.95680443e+12,  1.95680443e+12, -9.89470362e+10, -9.89470362e+10,
#        -9.89470362e+10, -9.89470362e+10, -9.89470362e+10, -9.89470362e+10,
#        -9.89470362e+10, -6.92652366e+10, -6.92652366e+10, -6.92652366e+10,
#        -6.92652366e+10, -6.92652366e+10, -6.92652366e+10, -3.95834370e+10,
#        -3.95834370e+10, -3.95834370e+10, -3.95834370e+10, -3.95834370e+10,
#        -3.95834370e+10, -9.90163742e+09, -9.90163742e+09, -9.90163743e+09,
#         1.97801622e+10,  1.97801622e+10,  1.47631836e+00, -2.96817996e+10,
#         1.11242676e+00, -3.21289062e-01])

# %%
#Defininf y predicted for training
y_pred = regressor.predict(X)
# Calculating R2 for training
r2_score(y, y_pred)
# Out:
# 0.7886429518243268

# %% [markdown]
# ## Making Predictions

# %%
# Defining test set
X = test_set.drop('cnt', axis = 1).values
y = test_set['cnt'].values
# Predicting Test Set
y_pred = regressor.predict(X)
# Calculating R2
r2_score(y, y_pred)
# Out:
# 0.7373472574593908

# %% [markdown]
# R2 score for training is  0.737 which is less than the training 0.788. Since they are very similar their is a low risk of overfitting

# %%
df = pd.DataFrame({'Actual': y, 'Predicted': y_pred})

# %%
# Simple plot to check the predictions
plt.scatter(y, y_pred)

# %% [markdown]
# ## Evaluating Algorithm

# %%
from sklearn import metrics
# Calculating R2
r2 = r2_score(y, y_pred)
print('R square:', r2)
#Calculating other Metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# R square: 0.7373472574593908
# Mean Absolute Error: 2.8490764181555286
# Mean Squared Error: 13.310834996433739
# Root Mean Squared Error: 3.648401704367782

# %% [markdown]
# ## Model: Ridge Linear Regression

# %%
# Split the train set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)
train_set = pd.DataFrame(train_set)
X = train_set.drop('cnt', axis = 1).values
y = train_set['cnt'].values
#Checking shape
print(X.shape, y.shape)
# Out:
# (15212, 50) (15212,)

# %%
#Dowloading Gridsearch
from sklearn.model_selection import  GridSearchCV

# %%
#Training the Algorithm
from sklearn.linear_model import LinearRegression, Ridge
regressor = Ridge()
params = [{"alpha": [10,20,100,150,]}]
GridSearch = GridSearchCV(regressor, cv= 10, param_grid= params)
GridSearch.fit(X, y)
print(GridSearch.best_params_)
# Out:
# {'alpha': 20}

# %%
#Runing model to predict training set
y_pred = GridSearch.best_estimator_.predict(X)
r2_score(y, y_pred) #R2 of trainig set predicted
# Out:
# 0.7880990943894336

# %% [markdown]
# ## Prediction
#
# Predicting the counts for the test data

# %%
# Split the test set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)
X = test_set.drop('cnt', axis = 1).values
y = test_set['cnt'].values

# %%
# Modeling the test set
y_pred = GridSearch.best_estimator_.predict(X)
r2_score(y, y_pred) #R2 for test prediction
# Out:
# 0.7337694944363801

# %% [markdown]
# The training R2 (0.788)is bigger than the test R2(0.733) indicating that there could by bias on the model

# %% [markdown]
# ## Lasso Model with cross Validation

# %%
from sklearn.linear_model import LassoCV, Lasso

# %%
# Split the train set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)
X = train_set.drop('cnt', axis = 1).values
y = train_set['cnt'].values

# %%
# Define alpha space to select the best alphas (we use logspace in order to search for very small numbers close to cero)
alpha_space = np.logspace(-4, 0, 50)
alpha_space
# Out:
# array([1.00000000e-04, 1.20679264e-04, 1.45634848e-04, 1.75751062e-04,
#        2.12095089e-04, 2.55954792e-04, 3.08884360e-04, 3.72759372e-04,
#        4.49843267e-04, 5.42867544e-04, 6.55128557e-04, 7.90604321e-04,
#        9.54095476e-04, 1.15139540e-03, 1.38949549e-03, 1.67683294e-03,
#        2.02358965e-03, 2.44205309e-03, 2.94705170e-03, 3.55648031e-03,
#        4.29193426e-03, 5.17947468e-03, 6.25055193e-03, 7.54312006e-03,
#        9.10298178e-03, 1.09854114e-02, 1.32571137e-02, 1.59985872e-02,
#        1.93069773e-02, 2.32995181e-02, 2.81176870e-02, 3.39322177e-02,
#        4.09491506e-02, 4.94171336e-02, 5.96362332e-02, 7.19685673e-02,
#        8.68511374e-02, 1.04811313e-01, 1.26485522e-01, 1.52641797e-01,
#        1.84206997e-01, 2.22299648e-01, 2.68269580e-01, 3.23745754e-01,
#        3.90693994e-01, 4.71486636e-01, 5.68986603e-01, 6.86648845e-01,
#        8.28642773e-01, 1.00000000e+00])

# %%
# Define a cross validated lasso regression optimisation model that takes all the numbers in the alpha space to find one that minimizes mean squared error. 
lassocv = LassoCV(cv = 10, alphas = alpha_space, normalize = True,max_iter = 1e5)

# %%
# Train the lasso CV and find the Alpha that minimises the mean_squared error
lassocv.fit(X, y)
lassocv.alpha_
# Out:
# 0.0001

# %%
# Define a Lasso function with the alpha found in the lasso CV model
lasso = Lasso(alpha = lassocv.alpha_, normalize=True)

# %%
# Final model is the Lasso regression with the optimised Alpha
model = lasso.fit(X, y)

# %%
# Defining test set
X = test_set.drop('cnt', axis = 1).values
y = test_set['cnt'].values

# %%
# Predict the y for the test set
y_pred = model.predict(X)

# %%
# Check R2
lasso.score(X, y)
# Out:
# 0.7364521962692473

# %%
# Simple plot to check the predictions

plt.scatter(y, y_pred)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# Mean Absolute Error: 2.853664390443387
# Mean Squared Error: 13.35619531400921
# Root Mean Squared Error: 3.6546128815524646

# %% [markdown]
# ## Decision Tree Model with CV

# %%
from sklearn.model_selection import GridSearchCV
from pprint import pprint
from sklearn.tree import DecisionTreeRegressor

# %%
# Split the train set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)
train_set = pd.DataFrame(train_set)
X = train_set.drop('cnt', axis = 1).values
y = train_set['cnt'].values
print(X.shape, y.shape)
# Out:
# (15212, 50) (15212,)

# %%
tree = DecisionTreeRegressor()
parameters = {'max_depth':range(1,40)}
clf = GridSearchCV(tree,cv= 10, param_grid = parameters, n_jobs=10)

# %%
clf.fit(X, y)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=DecisionTreeRegressor(criterion='mse', max_depth=None,
#                                              max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              presort=False, random_state=None,
#                                              splitter='best'),
#              iid='warn', n_jobs=10, param_grid={'max_depth': range(1, 40)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)

# %%
tree_model = clf.best_estimator_
tree_model
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=18, max_features=None,
#                       max_leaf_nodes=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       presort=False, random_state=None, splitter='best')

# %%
# R2 before testing
y_pred = tree_model.predict(X)
r2_score(y, y_pred)
# Out:
# 0.9846064980057727

# %%
print (clf.best_params_)
# Out:
# {'max_depth': 18}

# %%
# Defining test set
X = test_set.drop('cnt', axis = 1).values
y = test_set['cnt'].values

# %%
y_pred = tree_model.predict(X)

# %%
# Simple plot to check the predictions
plt.scatter(y, y_pred)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# Mean Absolute Error: 2.1733555295603173
# Mean Squared Error: 10.208152589651345
# Root Mean Squared Error: 3.195019967019196

# %%
r2_score(y, y_pred) # R2 score
# Out:
# 0.7985701667353475

# %% [markdown]
# The test score is 0.8145 wich is less than the training score 0.9680. This indicates that the model is overfitted

# %% [markdown]
# # Best Models

# %% [markdown]
# ## Random Forest Model with CV and Grid Search

# %%
# Split the train set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)
train_set = pd.DataFrame(train_set)
X = train_set.drop('cnt', axis = 1).values
y = train_set['cnt'].values
print(X.shape, y.shape)
# Out:
# (15212, 50) (15212,)

# %%
# Loading Library
from sklearn.ensemble import RandomForestRegressor

# Defining model with no gridsearch
Forest = RandomForestRegressor(n_estimators=20, random_state=0)
Forest.fit(X, y)

# Defining and tuning with GridSearch model
parameters = {'max_depth':[10, 15], 'min_samples_split':[20,30,35,40], 'min_samples_leaf':[10], 'n_estimators':[20, 21, 22, 23], 'max_leaf_nodes':[85]}
RFR = GridSearchCV(Forest,cv= 10, param_grid = parameters, n_jobs=10)

# %%
# Running  tunned model in train set
RFR.fit(X, y)

# Best paramater selection and optimization
Forest_model = RFR.best_estimator_
Forest_model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=15,
#                       max_features='auto', max_leaf_nodes=85,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=10, min_samples_split=40,
#                       min_weight_fraction_leaf=0.0, n_estimators=21,
#                       n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                       warm_start=False)

# %%
# R2 of the No GridSearch model before testing 
y_pred = Forest_model.predict(X)
r2_score(y, y_pred)
# Out:
# 0.9024110554781015

# %%
hour_data.head()
# Out:
#                     yr mnth  windspeed       cnt  season_1  season_2  \
# dteday
# 2011-01-01 00:00:00  0    1        0.0  4.000000         1         0
# 2011-01-01 01:00:00  0    1        0.0  6.324555         1         0
# 2011-01-01 02:00:00  0    1        0.0  5.656854         1         0
# 2011-01-01 03:00:00  0    1        0.0  3.605551         1         0
# 2011-01-01 04:00:00  0    1        0.0  1.000000         1         0
#
#                      season_3  season_4  holiday_0  holiday_1  ...  \
# dteday                                                         ...
# 2011-01-01 00:00:00         0         0          1          0  ...
# 2011-01-01 01:00:00         0         0          1          0  ...
# 2011-01-01 02:00:00         0         0          1          0  ...
# 2011-01-01 03:00:00         0         0          1          0  ...
# 2011-01-01 04:00:00         0         0          1          0  ...
#
#                      hr_time_18  hr_time_19  hr_time_20  hr_time_21  \
# dteday
# 2011-01-01 00:00:00           0           0           0           0
# 2011-01-01 01:00:00           0           0           0           0
# 2011-01-01 02:00:00           0           0           0           0
# 2011-01-01 03:00:00           0           0           0           0
# 2011-01-01 04:00:00           0           0           0           0
#
#                      hr_time_22  hr_time_23  windspeed4  time_of_day  \
# dteday
# 2011-01-01 00:00:00           0           0         0.0            0
# 2011-01-01 01:00:00           0           0         0.0            0
# 2011-01-01 02:00:00           0           0         0.0            0
# 2011-01-01 03:00:00           0           0         0.0            0
# 2011-01-01 04:00:00           0           0         0.0            0
#
#                      temperature_bin  humidity_bin
# dteday
# 2011-01-01 00:00:00                0             3
# 2011-01-01 01:00:00                0             3
# 2011-01-01 02:00:00                0             3
# 2011-01-01 03:00:00                0             3
# 2011-01-01 04:00:00                0             3
#
# [5 rows x 51 columns]

# %%
# Defining test set for model with no gridsearch
X = test_set.drop('cnt', axis = 1).values
y = test_set['cnt'].values

# Predicting Y for model with no gridsearch
y_pred = Forest.predict(X)

# R2
r2_score(y, y_pred)
# Out:
# 0.870630568640802

# %% [markdown]
# 0.870630568640802 is the highest  r2 score among all models

# %% [markdown]
# # 0.87063 Best Score !

# %% [markdown]
# ## Random Forest Model with Ramdom Search

# %%
# Importing new Libraries
from sklearn.model_selection import RandomizedSearchCV

# %%
# Split the train set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)
train_set = pd.DataFrame(train_set)
X = train_set.drop('cnt', axis = 1).values
y = train_set['cnt'].values
print(X.shape, y.shape)
# Out:
# (15212, 50) (15212,)

# %%
# Defining Algorithm
Forest = RandomForestRegressor()
Forest.fit(X, y)

# RamdomSearch
# Defining Hiperparameters
max_depth = [10]
min_samples_split = [20,30,35,40]
min_samples_leaf = [10] 
bootstrap = [True]
n_estimators=[20, 21, 22, 23]
max_leaf_nodes = [85]

# Ramdom search optimization of hiperparameters
RFR = RandomizedSearchCV(Forest,cv= 10, param_distributions  = {'max_depth':max_depth, 'min_samples_split':min_samples_split, 'min_samples_leaf':min_samples_leaf, 'bootstrap':bootstrap, 'n_estimators': n_estimators, 'max_leaf_nodes': max_leaf_nodes},scoring="r2",verbose=0, n_jobs=4)

# %%
# Running model
RFR.fit(X, y)
print(RFR.best_params_)
# Out:
# {'n_estimators': 20, 'min_samples_split': 35, 'min_samples_leaf': 10, 'max_leaf_nodes': 85, 'max_depth': 10, 'bootstrap': True}

# %%
# R2 before testing
y_pred = Forest.predict(X)
r2_score(y, y_pred)
# Out:
# 0.9894141561193776

# %%
# Modeling test set
X = test_set.drop('cnt', axis = 1).values
y = test_set['cnt'].values
# Modeling
y_pred = Forest.predict(X)

# %%
r2_score(y, y_pred)
# Out:
# 0.8587863511318549

# %% [markdown]
# The model is overfited because the training R2 is 0.98 and the r2 test score is 0.85. Meaning that ther is over tunning.

# %% [markdown]
# # Spliting Dataset for PCA

# %%
# Spliting Dataset into test
X_pca=pd.DataFrame(X_pca,index=hour_data.index)
X_pca.insert(0,'cnt',hour_data['cnt'])
test_set= X_pca[X_pca.index >= "2012-10-01 00:00:00"]

# %%
# Spliting Dataset into training

# %%
train_set=pd.DataFrame(X_pca,index=hour_data.index)
train_set= X_pca[X_pca.index <= "2012-10-01 00:00:00"]

# %% [markdown]
# # Linear Model with PCA

# %%
# Split the train set into the independent and target variables
# Convert the variables to 2d numpy arrays (as required by sklearn)

train_set = pd.DataFrame(train_set)
X = train_set.drop('cnt', axis = 1).values
y = train_set['cnt'].values
print(X.shape, y.shape)
# Out:
# (15212, 20) (15212,)

# %%
#Training the Algorithm
regressor = LinearRegression()
regressor.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Printing regresion coeficients
regressor.coef_
# Out:
# array([-0.27385949,  2.48358623, -0.12129883,  0.6400129 , -0.05074822,
#         1.29807368,  0.64206215, -2.70719787, -0.27747178, -0.1338221 ,
#         0.17235486, -0.07616662,  0.06488446,  1.13178568, -1.66868118,
#         0.54282965, -0.73871131,  7.59565488, -3.15479958,  0.39602972])

# %%
# Predicting Validation set Set
y_pred = regressor.predict(X)
# Calculating R2
r2_score(y, y_pred)
# Out:
# 0.517987200089584

# %% [markdown]
# ## Making Predictions

# %%
# Defining test set
X = test_set.drop('cnt', axis = 1).values
y = test_set['cnt'].values
# Predicting Test Set
y_pred = regressor.predict(X)
# Calculating R2
r2_score(y, y_pred)
# Out:
# 0.4243179964331023

# %%
df = pd.DataFrame({'Actual': y, 'Predicted': y_pred})

# %%
# Simple plot to check the predictions

plt.scatter(y, y_pred)

# %% [markdown]
# ## Evaluating Algorithm

# %%
from sklearn import metrics
# Calculating R2
r2 = r2_score(y, y_pred)
print('R square:', r2)
# Calculating other Metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y, y_pred)))
# Out:
# R square: 0.4243179964331023
# Mean Absolute Error: 4.376586219424354
# Mean Squared Error: 29.174674080209133
# Root Mean Squared Error: 5.401358540238662

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We can conclude that Random Forest is the most efficient model for predicting total rental bikes. The highest R2 score with this model was 0.87. Furthermore, creating the bin features where we divided temperature, wind and humidity in different categories is very useful for optimizing the r2 score. Additionally, running PCA in a small dataset is not appropriate and it is evident in the results obtained in the linear model (0.424). GridSearchCV is a good tool for tuning the models, it helped a lot for searching for the right hyper parameters, before using GridSearch the models were not performing as efficient as the Random Forest Model (0.87).
#
# For further work we recommend creating new features by combining climate variables such as Temperature, humidity and wind. Also searching for new data in Washington, DC such as bike prices, pollution ratios, traffic jam and many more is a good starting point for improving the target variable prediction. After adding all this features, a Chi-Square dimensionality reduction will be a good idea.
